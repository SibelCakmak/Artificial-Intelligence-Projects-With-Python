# %%
import numpy as np
import pandas as pd 
from sklearn import tree

# %%
data = pd.read_csv("DecisionTreesClassificationDataSet.csv")
data
# Out:
#     Deneyim Yili SuanCalisiyor?  Eski Calistigi Firmalar Egitim Seviyesi  \
# 0             11              Y                        4              BS
# 1              0              N                        0             PhD
# 2              5              Y                        2              MS
# 3              3              N                        1              BS
# 4              0              N                        0              BS
# 5             14              Y                        7              BS
# 6              1              N                        0              BS
# 7              1              N                        1             PhD
# 8              4              Y                        1              BS
# 9              0              N                        0             PhD
# 10             0              N                        0              BS
# 11             2              N                        0              BS
# 12             8              N                        6              BS
# 13             3              Y                        1              MS
# 14            19              N                        2             PhD
# 15             1              N                        0              BS
#
#    Top10 Universite? StajBizdeYaptimi? IseAlindi
# 0                  N                 N         Y
# 1                  Y                 Y         Y
# 2                  N                 Y         Y
# 3                  N                 Y         Y
# 4                  N                 N         N
# 5                  N                 N         Y
# 6                  N                 N         N
# 7                  Y                 N         N
# 8                  N                 Y         Y
# 9                  Y                 N         Y
# 10                 Y                 Y         Y
# 11                 Y                 Y         Y
# 12                 N                 N         N
# 13                 Y                 N         Y
# 14                 Y                 N         N
# 15                 N                 N         N

# %% [markdown]
# scikit-learn kütüphanesi decision tree'lerin düzgün çalışması için herşeyin rakamlsal olmasını bekliyor bu nedenle veri setimizdeki tüm Y ve N değerlerini 0 ve 1 olarak düzeltiyoruz. Aynı sebeple eğitim seviyesini de BS:0 MS:1 ve PhD:2 olarak güncelliyoruz. map() kullanarak boş hücreler veya geçersiz değer girilen hücreler NaN ile doldurulacaktır, buna şuandaki veri setimizde ihtiyacıkız yok ama sizin ilerde yoğun veri ile çalıştığınız zaman ihtiyacınız olacaktır.

# %%
duzelme_mapping = {'Y':1,'N':0}
data['IseAlindi'] = data['IseAlindi'].map(duzelme_mapping)
data['StajBizdeYaptimi?'] = data['StajBizdeYaptimi?'].map(duzelme_mapping)
data['Top10 Universite?'] = data['Top10 Universite?'].map(duzelme_mapping)
data['SuanCalisiyor?'] = data['SuanCalisiyor?'].map(duzelme_mapping)

# %%
duzelme_mapping_egitim = {'BS':0,'PhD':1,'MS':2}
data['Egitim Seviyesi'] = data['Egitim Seviyesi'].map(duzelme_mapping_egitim)

# %%
data
# Out:
#     Deneyim Yili  SuanCalisiyor?  Eski Calistigi Firmalar  Egitim Seviyesi  \
# 0             11               1                        4                0
# 1              0               0                        0                1
# 2              5               1                        2                2
# 3              3               0                        1                0
# 4              0               0                        0                0
# 5             14               1                        7                0
# 6              1               0                        0                0
# 7              1               0                        1                1
# 8              4               1                        1                0
# 9              0               0                        0                1
# 10             0               0                        0                0
# 11             2               0                        0                0
# 12             8               0                        6                0
# 13             3               1                        1                2
# 14            19               0                        2                1
# 15             1               0                        0                0
#
#     Top10 Universite?  StajBizdeYaptimi?  IseAlindi
# 0                   0                  0          1
# 1                   1                  1          1
# 2                   0                  1          1
# 3                   0                  1          1
# 4                   0                  0          0
# 5                   0                  0          1
# 6                   0                  0          0
# 7                   1                  0          0
# 8                   0                  1          1
# 9                   1                  0          1
# 10                  1                  1          1
# 11                  1                  1          1
# 12                  0                  0          0
# 13                  1                  0          1
# 14                  1                  0          0
# 15                  0                  0          0

# %%
X = data.drop(['IseAlindi'], axis = 1)
y = data['IseAlindi']

# %%
dtree = tree.DecisionTreeClassifier()
dtree = dtree.fit(X.values,y)

# %%
# Prediction yapalım şimdi
# 5 yıl deneyimli, hazlihazırda bir yerde çalışan ve 3 eski şirkette çalışmış olan, eğitim seviyesi Lisans
# top-tier-school mezunu değil
print (dtree.predict([[5, 1, 3, 0, 0, 0]]))
# Out:
# [1]

# %%
# Toplam 2 yıllık iş deneyimi, 7 kez iş değiştirmiş çok iyi bir okul mezunu şuan çalışmıyor
print (dtree.predict([[2, 0, 7, 0, 1, 0]]))
# Out:
# [0]

# %%
# Toplam 2 yıllık iş deneyimi, 7 kez iş değiştirmiş çok iyi bir okul mezunu değil şuan çalışıyor
print (dtree.predict([[2, 1, 7, 0, 0, 0]]))
# Out:
# [1]
